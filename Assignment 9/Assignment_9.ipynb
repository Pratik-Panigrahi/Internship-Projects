# %%
import pandas  as pd
import numpy as np

# %%
import nltk, re
nltk.download('stopwords') # load english stopwords
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
import warnings
warnings.simplefilter("ignore")
warnings.warn("deprecated", DeprecationWarning)
warnings.simplefilter("ignore")
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\PRATIK
# [nltk_data]     PANIGRAHI\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
data=pd.read_csv(r'C:\Users\PRATIK PANIGRAHI\Desktop\NLP CLASSES\assignment 8\NLP Projects to do\Project_2\messages.csv')
data.head(5)
# Out:
#                                              subject  \
# 0            job posting - apple-iss research center
# 1                                                NaN
# 2  query : letter frequencies for text identifica...
# 3                                               risk
# 4                           request book information
#
#                                              message  label
# 0  content - length : 3386 apple-iss research cen...      0
# 1  lang classification grimes , joseph e . and ba...      0
# 2  i am posting this inquiry for sergei atamas ( ...      0
# 3  a colleague and i are researching the differin...      0
# 4  earlier this morning i was on the phone with a...      0

# %%
data=data.replace(np.nan,"",regex=True)
data.head()
# Out:
#                                              subject  \
# 0            job posting - apple-iss research center
# 1
# 2  query : letter frequencies for text identifica...
# 3                                               risk
# 4                           request book information
#
#                                              message  label
# 0  content - length : 3386 apple-iss research cen...      0
# 1  lang classification grimes , joseph e . and ba...      0
# 2  i am posting this inquiry for sergei atamas ( ...      0
# 3  a colleague and i are researching the differin...      0
# 4  earlier this morning i was on the phone with a...      0

# %%
data.columns
# Out:
# Index(['subject', 'message', 'label'], dtype='object')

# %%
data.isnull().sum()
# Out:
# subject    0
# message    0
# label      0
# dtype: int64

# %%
data.shape
# Out:
# (2893, 3)

# %%
data.dtypes
# Out:
# subject    object
# message    object
# label       int64
# dtype: object

# %%
import seaborn as sns
sns.countplot(x=data['label'])

# %%
#data['information']=data['subject'].str.cat(data['message'],sep=' ')
data['information']= data["subject"].astype(str) +" "+ data["message"]
data.head()
# Out:
#                                              subject  \
# 0            job posting - apple-iss research center
# 1
# 2  query : letter frequencies for text identifica...
# 3                                               risk
# 4                           request book information
#
#                                              message  label  \
# 0  content - length : 3386 apple-iss research cen...      0
# 1  lang classification grimes , joseph e . and ba...      0
# 2  i am posting this inquiry for sergei atamas ( ...      0
# 3  a colleague and i are researching the differin...      0
# 4  earlier this morning i was on the phone with a...      0
#
#                                          information
# 0  job posting - apple-iss research center conten...
# 1   lang classification grimes , joseph e . and b...
# 2  query : letter frequencies for text identifica...
# 3  risk a colleague and i are researching the dif...
# 4  request book information earlier this morning ...

# %%
data1=data.drop(['subject','message'],axis=1)

# %%
data1
# Out:
#       label                                        information
# 0         0  job posting - apple-iss research center conten...
# 1         0   lang classification grimes , joseph e . and b...
# 2         0  query : letter frequencies for text identifica...
# 3         0  risk a colleague and i are researching the dif...
# 4         0  request book information earlier this morning ...
# 5         0  call for abstracts : optimality in syntactic t...
# 6         0  m . a . in scandinavian linguistics m . a . in...
# 7         0  call for papers : linguistics session of the m...
# 8         0  foreign language in commercials content - leng...
# 9         0  fulbright announcement : please post / dissemi...
# 10        0  gala ' 95 : call for papers groningen assembly...
# 11        0  bu conf on language development ' 95 - announc...
# 12        0  korean software for macintosh dear sir / madam...
# 13        0   syntax the antisymmetry of syntax richard s ....
# 14        0  simultaneous prepositions and postpositions in...
# 15        0  sum : imperatives without you subjects content...
# 16        0  policies moderators ' message a very happy 199...
# 17        0  * * * correction to hellenistic greek announce...
# 18        0  question on audio samples i am looking for aud...
# 19        0  sexism and language re lydie e . meunier 's la...
# 20        0  teaching english in korea teaching english in ...
# 21        1  free this is a multi-part message in mime form...
# 22        0  email address for w . dressler colleagues - we...
# 23        0  dhumbadji ! , journal for the history of langu...
# 24        0  question : quantitative information hello , th...
# 25        0  re : amharic i am doing independent study on t...
# 26        0  uniformitarianism in response to the request f...
# 27        0  re : 6 . 1094 , qs : phonemicity of writing th...
# 28        0  intensive summer arabic language institute the...
# 29        0  lists on comparative literature content - leng...
# ...     ...                                                ...
# 2863      0  summary : even if dear linguists , on linguist...
# 2864      0  re : 6 . 797 , comparative method : n - ary co...
# 2865      0  q : incorporation in mandarin ? having recentl...
# 2866      1  wholesale club ! hi , we where wondering if yo...
# 2867      1  re : call me now 732-942 - 7100 hi sexy : i am...
# 2868      1  http : / / www . xxxnet . cx the most nasty , ...
# 2869      0  summary of responses to query on tok masta ( f...
# 2870      1  this is new on 95 . 8 capital fm to unsubscrib...
# 2871      0  sum : verbal humour content - length : 4144 de...
# 2872      0  subcategorization in tranformational grammar d...
# 2873      0  parsers for russian this query was also posted...
# 2874      0  case studies needed dear colleagues , i ' m pr...
# 2875      0  re : 8 . 1107 , qs : lang . games , " democrat...
# 2876      0  indoeuropean courses listed by universities ( ...
# 2877      0  job : indonesian / asian studies lecturer ( in...
# 2878      0  re : 6 . 797 , comparative method : n - ary co...
# 2879      0  summary : heavy onsets references original que...
# 2880      0  sum master 's dissertation dear netters , abou...
# 2881      0  internships in israel i have recently moved to...
# 2882      1  accept credit cards and watch sales skyrocket ...
# 2883      0  evolvable hardware and gp paper now available ...
# 2884      1  did that work for you ? - calsvxtn hello thank...
# 2885      0  british vs . american < a > ( s griffin bacal ...
# 2886      1  from fanny , recommending nek dear sir or mada...
# 2887      1  win $ 300usd and a cruise ! raquel 's casino ,...
# 2888      1  love your profile - ysuolvpv hello thanks for ...
# 2889      1  you have been asked to join kiddin the list ow...
# 2890      0  anglicization of composers ' names judging fro...
# 2891      0  re : 6 . 797 , comparative method : n - ary co...
# 2892      0  re : american - english in australia hello ! i...
#
# [2893 rows x 2 columns]

# %%
data1['label'].value_counts()
# Out:
# 0    2412
# 1     481
# Name: label, dtype: int64

# %%
import seaborn as sns
sns.countplot(x=data1['label'])

# %%
#New column for Length of message
data1['length'] = data1.information.str.len()
data1.head(100)
# Out:
#     label                                        information  length
# 0       0  job posting - apple-iss research center conten...    2896
# 1       0   lang classification grimes , joseph e . and b...    1801
# 2       0  query : letter frequencies for text identifica...    1486
# 3       0  risk a colleague and i are researching the dif...     329
# 4       0  request book information earlier this morning ...    1071
# 5       0  call for abstracts : optimality in syntactic t...    4544
# 6       0  m . a . in scandinavian linguistics m . a . in...    2237
# 7       0  call for papers : linguistics session of the m...     855
# 8       0  foreign language in commercials content - leng...    1262
# 9       0  fulbright announcement : please post / dissemi...    1538
# 10      0  gala ' 95 : call for papers groningen assembly...    2500
# 11      0  bu conf on language development ' 95 - announc...    2156
# 12      0  korean software for macintosh dear sir / madam...     147
# 13      0   syntax the antisymmetry of syntax richard s ....     800
# 14      0  simultaneous prepositions and postpositions in...    1186
# 15      0  sum : imperatives without you subjects content...    2971
# 16      0  policies moderators ' message a very happy 199...    6245
# 17      0  * * * correction to hellenistic greek announce...     476
# 18      0  question on audio samples i am looking for aud...     501
# 19      0  sexism and language re lydie e . meunier 's la...    1371
# 20      0  teaching english in korea teaching english in ...    1545
# 21      1  free this is a multi-part message in mime form...   18442
# 22      0  email address for w . dressler colleagues - we...     882
# 23      0  dhumbadji ! , journal for the history of langu...     791
# 24      0  question : quantitative information hello , th...     400
# 25      0  re : amharic i am doing independent study on t...     335
# 26      0  uniformitarianism in response to the request f...    1135
# 27      0  re : 6 . 1094 , qs : phonemicity of writing th...    1582
# 28      0  intensive summer arabic language institute the...     442
# 29      0  lists on comparative literature content - leng...     667
# ..    ...                                                ...     ...
# 70      0  french / english neologisms hi , i am new to t...    2669
# 71      0  wrong lctl gopher path last week , i announced...    1206
# 72      0  qs : syllabus for english linguistics i will b...     361
# 73      0  wccfl predication workshop preliminary program...     828
# 74      0  summer opportunities hey ! does anyone know of...     359
# 75      0  references in slavic syntax dear linguists , i...     634
# 76      0  grammatical relations and derived notions abou...    2773
# 77      0  sapir - whorf sapir-whorf hypothesis i know li...    1333
# 78      0  qs re phonetics lab for mac or pc we would lik...     828
# 79      0  japanese specialist needed the linguistics res...    1129
# 80      0  the other side of * galicismos * * galicismo *...     480
# 81      0  references on non-human language content - len...    5435
# 82      0  sum : v - initial languages several weeks ago ...    6779
# 83      0  escol ' 95 * preliminary program and registrat...    5689
# 84      1  free stealth 3 . 0 bulk email software . . . j...    8217
# 85      1  need more money ? hi , would you like to earn ...   11826
# 86      1  cable decsrambler now only $ 6 . 99 ! this is ...    2199
# 87      0  international sign linguistics association con...    5739
# 88      0  ceth summer seminar on electronic texts in the...    7473
# 89      0  summary : borrowings or replacements of ' ear ...    3596
# 90      0  summary : german terms for sibilant , shibilan...    1105
# 91      0  eskimo snow and scottish rain i do n't know ab...     436
# 92      1  as you requested - - free samples and informat...    1207
# 93      1  the best software @ the best $ remove instruct...    7193
# 94      1  hey there interested in some free xxx site 's ...     297
# 95      0  job announcement for a spanish sociolinguist a...    1165
# 96      0  seeking langacker reference in a paper by rona...     583
# 97      0  he / she > > jeffrey weber replies : > 1 ) my ...     981
# 98      0  developments in discourse analysis ( gls 1995 ...   10667
# 99      0  summary of multimodal refs summary to my query...    8405
#
# [100 rows x 3 columns]

# %%
data1.shape
# Out:
# (2893, 3)

# %%
def lower_case(series):
    return series.lower()

# %%
data1['information']=data1['information'].apply(lower_case)

# %%
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;-_*0-9+]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
def text_prepare(series):
    series=re.sub(r'^.+@[^\.].*\.[a-z]{2,}$','email',series)
    series=re.sub(r'^http\://[a-z0-9\-\.]+\.[a-z]{2,3}(/\S*)?$','webaddress',series)
    series=re.sub(r'^\(?[\d]{3}\)?[\s-]?[\d]{3}[\s-]?[\d]{4}$','number',series)
    series=re.sub(r'\d+(\.\d+)?', 'numbr',series)
    series=re.sub(REPLACE_BY_SPACE_RE," ",series)
    series = re.sub(BAD_SYMBOLS_RE," ",series)
    series = re.sub(r'\s+'," ",series)
    return series

# %%
tests = ["SQL server - any equivalent of Excel's CHOOSE function_?164441545, - https://medium.com/@datamonsters",
        "How to free  c++ memory vector<int> * arr?"]
for test in tests: print(text_prepare(test))
# Out:
#  server any equivalent of xcel s function numbr https medium com datamonsters
#  ow to free c memory vector int arr

# %%
data1['information']=data1['information'].map(text_prepare)
data1
# Out:
#       label                                        information  length
# 0         0  job posting apple iss research center content ...    2896
# 1         0   lang classification grimes joseph e and barba...    1801
# 2         0  query letter frequencies for text identificati...    1486
# 3         0  risk a colleague and i are researching the dif...     329
# 4         0  request book information earlier this morning ...    1071
# 5         0  call for abstracts optimality in syntactic the...    4544
# 6         0  m a in scandinavian linguistics m a in scandin...    2237
# 7         0  call for papers linguistics session of the m m...     855
# 8         0  foreign language in commercials content length...    1262
# 9         0  fulbright announcement please post disseminate...    1538
# 10        0  gala numbr call for papers groningen assembly ...    2500
# 11        0  bu conf on language development numbr announce...    2156
# 12        0  korean software for macintosh dear sir madam w...     147
# 13        0   syntax the antisymmetry of syntax richard s k...     800
# 14        0  simultaneous prepositions and postpositions in...    1186
# 15        0  sum imperatives without you subjects content l...    2971
# 16        0  policies moderators message a very happy numbr...    6245
# 17        0   correction to hellenistic greek announcement ...     476
# 18        0  question on audio samples i am looking for aud...     501
# 19        0  sexism and language re lydie e meunier s lates...    1371
# 20        0  teaching english in korea teaching english in ...    1545
# 21        1  free this is a multi part message in mime form...   18442
# 22        0  email address for w dressler colleagues we are...     882
# 23        0  dhumbadji journal for the history of language ...     791
# 24        0  question quantitative information hello there ...     400
# 25        0  re amharic i am doing independent study on the...     335
# 26        0  uniformitarianism in response to the request f...    1135
# 27        0  re numbr numbr qs phonemicity of writing this ...    1582
# 28        0  intensive summer arabic language institute the...     442
# 29        0  lists on comparative literature content length...     667
# ...     ...                                                ...     ...
# 2863      0  summary even if dear linguists on linguist lis...    7460
# 2864      0  re numbr numbr comparative method n ary compar...    1769
# 2865      0  q incorporation in mandarin having recently ar...    1189
# 2866      1  wholesale club hi we where wondering if you wo...     531
# 2867      1  re call me now numbr numbr numbr hi sexy i am ...    1281
# 2868      1  http www xxxnet cx the most nasty raunchy adul...     675
# 2869      0  summary of responses to query on tok masta ft ...    8064
# 2870      1  this is new on numbr numbr capital fm to unsub...    6276
# 2871      0  sum verbal humour content length numbr dear li...    4641
# 2872      0  subcategorization in tranformational grammar d...    1201
# 2873      0  parsers for russian this query was also posted...     695
# 2874      0  case studies needed dear colleagues i m prepar...    1087
# 2875      0  re numbr numbr qs lang games democratic word c...    1123
# 2876      0  indoeuropean courses listed by universities fa...     247
# 2877      0  job indonesian asian studies lecturer indonesi...    2709
# 2878      0  re numbr numbr comparative method n ary compar...     791
# 2879      0    summary heavy onsets references original query       51
# 2880      0  sum master s dissertation dear netters about a...     816
# 2881      0  internships in israel i have recently moved to...     558
# 2882      1  accept credit cards and watch sales skyrocket ...    2340
# 2883      0  evolvable hardware and gp paper now available ...    2158
# 2884      1  did that work for you calsvxtn hello thanks fo...     297
# 2885      0  british vs american a s griffin bacal internet...   14333
# 2886      1  from fanny recommending nek dear sir or madam ...    3049
# 2887      1  win numbrusd and a cruise raquel s casino inc ...     823
# 2888      1  love your profile ysuolvpv hello thanks for st...     291
# 2889      1  you have been asked to join kiddin the list ow...    2198
# 2890      0  anglicization of composers names judging from ...    1074
# 2891      0  re numbr numbr comparative method n ary compar...    3004
# 2892      0  re american english in australia hello i m wor...     737
#
# [2893 rows x 3 columns]

# %%
# Remove stopwords
import string
import nltk
from nltk.corpus import  stopwords

stop_words = set(stopwords.words('english') + ['u', 'ü', 'ur', '4', '2', 'im', 'dont', 'doin', 'ure'])

data1['information'] = data1['information'].apply(lambda x: ' '.join(
    term for term in x.split() if term not in stop_words))

# %%
# New column (clean_length) after puncuations,stopwords removal
data1['clean_length'] = data1.information.str.len()
data1
# Out:
#       label                                        information  length  \
# 0         0  job posting apple iss research center content ...    2896
# 1         0  lang classification grimes joseph e barbara f ...    1801
# 2         0  query letter frequencies text identification p...    1486
# 3         0  risk colleague researching differing degrees r...     329
# 4         0  request book information earlier morning phone...    1071
# 5         0  call abstracts optimality syntactic theory con...    4544
# 6         0  scandinavian linguistics scandinavian linguist...    2237
# 7         0  call papers linguistics session mla call paper...     855
# 8         0  foreign language commercials content length nu...    1262
# 9         0  fulbright announcement please post disseminate...    1538
# 10        0  gala numbr call papers groningen assembly lang...    2500
# 11        0  bu conf language development numbr announcemen...    2156
# 12        0  korean software macintosh dear sir madam would...     147
# 13        0  syntax antisymmetry syntax richard kayne lingu...     800
# 14        0  simultaneous prepositions postpositions pashto...    1186
# 15        0  sum imperatives without subjects content lengt...    2971
# 16        0  policies moderators message happy numbr subscr...    6245
# 17        0  correction hellenistic greek announcement coup...     476
# 18        0  question audio samples looking audio samples e...     501
# 19        0  sexism language lydie e meunier latest mean sa...    1371
# 20        0  teaching english korea teaching english korea ...    1545
# 21        1  free multi part message mime format nextpart n...   18442
# 22        0  email address w dressler colleagues trying con...     882
# 23        0  dhumbadji journal history language good news s...     791
# 24        0  question quantitative information hello someon...     400
# 25        0  amharic independent study rift valley africa a...     335
# 26        0  uniformitarianism response request info topic ...    1135
# 27        0  numbr numbr qs phonemicity writing stimulated ...    1582
# 28        0  intensive summer arabic language institute geo...     442
# 29        0  lists comparative literature content length nu...     667
# ...     ...                                                ...     ...
# 2863      0  summary even dear linguists linguist list vol ...    7460
# 2864      0  numbr numbr comparative method n ary compariso...    1769
# 2865      0  q incorporation mandarin recently arrived taiw...    1189
# 2866      1  wholesale club hi wondering would interested s...     531
# 2867      1  call numbr numbr numbr hi sexy considered one ...    1281
# 2868      1  http www xxxnet cx nasty raunchy adult interac...     675
# 2869      0  summary responses query tok masta ft new guine...    8064
# 2870      1  new numbr numbr capital fm unsubscribe e mails...    6276
# 2871      0  sum verbal humour content length numbr dear li...    4641
# 2872      0  subcategorization tranformational grammar dear...    1201
# 2873      0  parsers russian query also posted seelangs apo...     695
# 2874      0  case studies needed dear colleagues preparing ...    1087
# 2875      0  numbr numbr qs lang games democratic word chan...    1123
# 2876      0  indoeuropean courses listed universities fall ...     247
# 2877      0  job indonesian asian studies lecturer indonesi...    2709
# 2878      0  numbr numbr comparative method n ary compariso...     791
# 2879      0     summary heavy onsets references original query      51
# 2880      0  sum master dissertation dear netters week ago ...     816
# 2881      0  internships israel recently moved israel study...     558
# 2882      1  accept credit cards watch sales skyrocket incr...    2340
# 2883      0  evolvable hardware gp paper available post scr...    2158
# 2884      1  work calsvxtn hello thanks stopping taken many...     297
# 2885      0  british vs american griffin bacal internet mai...   14333
# 2886      1  fanny recommending nek dear sir madam spam mes...    3049
# 2887      1  win numbrusd cruise raquel casino inc awarding...     823
# 2888      1  love profile ysuolvpv hello thanks stopping ta...     291
# 2889      1  asked join kiddin list owner kiddin invited jo...    2198
# 2890      0  anglicization composers names judging return p...    1074
# 2891      0  numbr numbr comparative method n ary compariso...    3004
# 2892      0  american english australia hello working thesi...     737
#
#       clean_length
# 0             2077
# 1             1430
# 2             1109
# 3              215
# 4              654
# 5             3399
# 6             1604
# 7              693
# 8              829
# 9             1273
# 10            1776
# 11            1487
# 12             113
# 13             672
# 14             772
# 15            2136
# 16            3801
# 17             350
# 18             388
# 19             806
# 20            1227
# 21           16149
# 22             452
# 23             527
# 24             276
# 25             218
# 26             771
# 27            1050
# 28             361
# 29             311
# ...            ...
# 2863          4394
# 2864          1130
# 2865           869
# 2866           357
# 2867           750
# 2868           472
# 2869          4380
# 2870          3594
# 2871          3484
# 2872           808
# 2873           488
# 2874           775
# 2875           813
# 2876           211
# 2877          1857
# 2878           572
# 2879            46
# 2880           670
# 2881           407
# 2882          1497
# 2883          1744
# 2884           146
# 2885          8378
# 2886          1817
# 2887           492
# 2888           154
# 2889          1235
# 2890           673
# 2891          1921
# 2892           461
#
# [2893 rows x 4 columns]

# %%
print('original length',data1.length.sum())
print('clean length',data1.clean_length.sum())
# Out:
# original length 9439299
# clean length 6643971

# %%
# Message distribution BEFORE cleaning
import matplotlib.pyplot as plt
f,ax = plt.subplots(1,2,figsize = (15,8))

sns.distplot(data1[data1['label']==1]['length'],bins=20,ax=ax[0],label='Spam messages distribution',color='r')

ax[0].set_xlabel('Spam data1 length')
ax[0].legend()

sns.distplot(data1[data1['label']==0]['length'],bins=20,ax=ax[1],label='ham messages distribution')
ax[1].set_xlabel('ham data1 length')
ax[1].legend()

plt.show()

# %%
# Message distribution AFTER cleaning
f,ax = plt.subplots(1,2,figsize = (15,8))

sns.distplot(data1[data1['label']==1]['clean_length'],bins=20,ax=ax[0],label='Spam messages distribution',color='r')
ax[0].set_xlabel('Spam data1 length')
ax[0].legend()

sns.distplot(data1[data1['label']==0]['clean_length'],bins=20,ax=ax[1],label='ham messages distribution')
ax[1].set_xlabel('ham data1 length')
ax[1].legend()

plt.show()

# %%
#Getting sense of loud words in spam 
from wordcloud import WordCloud


spams = data1['information'][data1['label']==1]

spam_cloud = WordCloud(width=700,height=500,background_color='white',max_words=50).generate(' '.join(spams))

plt.figure(figsize=(10,8),facecolor='r')
plt.imshow(spam_cloud)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
#Getting sense of loud words in ham 

hams = data1['information'][data1['label']==0]
spam_cloud = WordCloud(width=600,height=400,background_color='white',max_words=50).generate(' '.join(hams))
plt.figure(figsize=(10,8),facecolor='k')
plt.imshow(spam_cloud)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
# 1. Convert text into vectors using TF-IDF
# 2. Instantiate MultinomialNB classifier
# 3. Split feature and label
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report,log_loss

tf_vec = TfidfVectorizer()

naive = MultinomialNB()

features = tf_vec.fit_transform(data1['information'])

X = features
y = data1['label']

# %%
from sklearn.model_selection import train_test_split
X_train,x_test,Y_train,y_test=train_test_split(X,y,train_size=0.7)

# %%
#performing over sampling to reduce the over fitting
from imblearn.over_sampling import RandomOverSampler
os=RandomOverSampler(0.70)
X_train_ns,Y_train_ns=os.fit_sample(X_train,Y_train)
print("The number of classes before fit {}".format(Counter(Y_train)))
print("The number of classes after fit {}".format(Counter(Y_train_ns)))
# Out:
# The number of classes before fit Counter({0: 1694, 1: 331})
# The number of classes after fit Counter({0: 1694, 1: 1185})

# %%
naive.fit(X_train_ns,Y_train_ns)

y_pred= naive.predict(x_test)

print ('Final score = > ', accuracy_score(y_test,y_pred))
# Out:
# Final score = >  0.9953917050691244

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       718
#            1       0.98      0.99      0.99       150
#
#     accuracy                           1.00       868
#    macro avg       0.99      0.99      0.99       868
# weighted avg       1.00      1.00      1.00       868

# %%
conf_mat
# Out:
# array([[715,   3],
#        [  1, 149]], dtype=int64)

# %%
# plot confusion matrix heatmap
conf_mat = confusion_matrix(y_test,y_pred)

ax=plt.subplot()

sns.heatmap(conf_mat,annot=True,ax=ax,linewidths=5,linecolor='y',center=0)

ax.set_xlabel('Predicted Labels');ax.set_ylabel('True Labels')

ax.set_title('Confusion matrix')
ax.xaxis.set_ticklabels(['ham','spam'])
ax.yaxis.set_ticklabels(['ham','spam'])
plt.show()

# %%
#Log loss metrics
log=log_loss(y_test,y_pred)

# %%
print(log)
# Out:
# 0.1591676317649011

# %% [markdown]
# After building the model i got 99 percent accuracy and log_loss metrice value 0.15.

# %%
import pickle 
  
# Save the trained model as a pickle string. 
saved_model = pickle.dumps(naive) 
  
# Load the pickled model 
naive_from_pickle = pickle.loads(saved_model) 
  
# Use the loaded pickled model to make predictions 
naive_from_pickle.predict(X_test)

# %%
#saving the model as pickl
from sklearn.externals import joblib
joblib.dump(naive,"spam_classification_Pratik.pkl")
# Out:
# ['spam_classification_Pratik.pkl']
